# %%
import pandas as pd
import numpy as np

import re

with open("conbog2019.txt","r") as f:
    data = f.readlines()
lista = {}
for line in data:
    words = re.sub(",","",line).split("\t")
    partidos=words[0].split(' ', 1)[1]
    votos=int(words[1].replace(".", ""))
    lista[partidos]=votos
    
#print(lista)    
parties = sorted(lista, key=lista.get, reverse=True)
vot = list(lista.values())
vot = sorted(vot, reverse=True)
vt= sum(vot)

vpp = list(vot)
pr = []
for i in vpp:
    a=(i/vt)*100
    pr.append(a)
    
l=len(lista)
cu = [0]*l
escaños = 0

while escaños < 45:
    a = vpp.index(max(vpp))
    cu[a] += 1
    m = vot[a]/(cu[a]+1)  
    vpp[a] = m
    escaños += 1
    #print(m)

df2 = pd.DataFrame()
#df2 = df2.rename(columns={0:'CALCULO DE REPARTICIÓN DE CURULES SEGUN BOLETÍN #'})
df2['CALCULO DE REPARTICIÓN DE CURULES SEGUN BOLETÍN #']=1
df1 = pd.DataFrame()
df1 = df1.rename(columns={0:'Partido'})
df1['Partido'] = parties
df1['Votación'] = vot
df1['Porcentaje %']= pd.DataFrame(pr)
df1['Curules'] = cu
df1.loc['Total'] = pd.Series(df['Curules'].sum(), index = ['Curules'])


#display(df2)
display(df1)
# Out:
#                                      Partido  Votación  Porcentaje %  Curules
# 0                             CAMBIO RADICAL    371134     17.632376        9
# 1                         CENTRO DEMOCRÁTICO    271828     12.914401        6
# 2                         LIBERAL COLOMBIANO    269141     12.786743        6
# 3                              ALIANZA VERDE    255263     12.127407        6
# 4               POLO DEMOCRÁTICO ALTERNATIVO    227178     10.793104        5
# 5                                    DE LA U    201587      9.577289        4
# 6                     CONSERVADOR COLOMBIANO    124319      5.906328        3
# 7                                       MIRA    105370      5.006072        2
# 8                                     LIBRES     69861      3.319058        1
# 9   SIGNIFICATIVO DE CIUDADANOS PROGRESISTAS     58316      2.770562        1
# 10              ALIANZA SOCIAL INDEPENDIENTE     48961      2.326111        1
# 11                          OPCIÓN CIUDADANA     41489      1.971120        1
# 12                          UNIÓN PATRIÓTICA     38726      1.839851        0
# 13      ALTERNATIVO INDÍGENA Y SOCIAL "MAIS"     12061      0.573012        0
# 14         AUTORIDADES INDÍGENAS DE COLOMBIA      9610      0.456566        0
